# %% [markdown]
# # Evaluate Neural Network

# %%
# Classification template
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('4_Churn_Modelling.csv')
X = dataset.iloc[:, 3:13].values   # upperbound is not included
y = dataset.iloc[:, 13].values    # class
df_X = pd.DataFrame(X)

# %% [markdown]
# #### Before split dataset in training set and test set we have to transform the categorical data in numerical data

# %%
# Encoding categorical data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_1 = LabelEncoder()
X[:, 1] = labelencoder_X_1.fit_transform(X[:, 1])

labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])

## Create the dummy variables
onehotencoder = OneHotEncoder(categorical_features = [1])
X = onehotencoder.fit_transform(X).toarray()

## is not necessary to do the same for Male and Female because is a binary value
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Feature Scaling
# Feature scaling is a method used to normalize the range of independent variables or features of data. 
# In data processing, it is also known as data normalization and is generally performed during 
# the data preprocessing step.
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Out:
# /Users/Paola/opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /Users/Paola/opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)

# %% [markdown]
# ## Now our data are well preprocessed!  Let's import keras libraries

# %%
import keras # using tendorflow backend
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# let's build a classifier. Our ANN is a Sequential of layers
# The model needs to know what input shape it should expect. For this reason, the first layer in a Sequential model (and only the first, because following layers can do automatic shape inference) needs to receive information about its input shape.

# %%
classifier = Sequential()

# We need 12 input nodes 

# We use a Rectifier activation function for the hidden layer 

# We use a Sigmoid activation function for the putput layer so we will be able to see which customer 
# has higher probability to leave the bank

# %%
# adding the first hidden layer 
classifier.add(Dense(output_dim = 7, init = 'uniform', activation = 'relu', input_dim = 12 ))

# adding the second hidden layer 
classifier.add(Dense(output_dim = 7, init = 'uniform', activation = 'relu'))

# adding the output layer 
classifier.add(Dense(output_dim = 1, init = 'uniform', activation = 'sigmoid')) # sigmoid 

# KEEP IN MIND : for more than 2 categories you'll use SOFTMAX function
# compile the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy' , metrics = ['accuracy'] )

# Fitting the ANN with the training set 
h = classifier.fit(X_train, y_train, batch_size =80  , nb_epoch = 100) 

y_pred  = classifier.predict(X_test)
# Out:
# /Users/Paola/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=12, units=7, kernel_initializer="uniform")`
#
# /Users/Paola/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=7, kernel_initializer="uniform")`
#   """
# /Users/Paola/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1, kernel_initializer="uniform")`
#
# /Users/Paola/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   from ipykernel import kernelapp as app
# Epoch 1/100
# 8000/8000 [==============================] - 0s 22us/step - loss: 0.6633 - accuracy: 0.7934
# Epoch 2/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.5050 - accuracy: 0.7960
# Epoch 3/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4424 - accuracy: 0.7960
# Epoch 4/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4354 - accuracy: 0.7960
# Epoch 5/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4319 - accuracy: 0.7960
# Epoch 6/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4298 - accuracy: 0.7960
# Epoch 7/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4279 - accuracy: 0.7960
# Epoch 8/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4264 - accuracy: 0.7960
# Epoch 9/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4253 - accuracy: 0.7960
# Epoch 10/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4236 - accuracy: 0.7960
# Epoch 11/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4218 - accuracy: 0.7960
# Epoch 12/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4204 - accuracy: 0.7960
# Epoch 13/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4192 - accuracy: 0.7960
# Epoch 14/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4185 - accuracy: 0.8033
# Epoch 15/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4177 - accuracy: 0.8207
# Epoch 16/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4169 - accuracy: 0.8227
# Epoch 17/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4160 - accuracy: 0.8238
# Epoch 18/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4154 - accuracy: 0.8260
# Epoch 19/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4150 - accuracy: 0.8269
# Epoch 20/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4142 - accuracy: 0.8289
# Epoch 21/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4138 - accuracy: 0.8289
# Epoch 22/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4131 - accuracy: 0.8296
# Epoch 23/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4127 - accuracy: 0.8294
# Epoch 24/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4119 - accuracy: 0.8299
# Epoch 25/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4114 - accuracy: 0.8306
# Epoch 26/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4108 - accuracy: 0.8322
# Epoch 27/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4105 - accuracy: 0.8316
# Epoch 28/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4100 - accuracy: 0.8325
# Epoch 29/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4094 - accuracy: 0.8328
# Epoch 30/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4088 - accuracy: 0.8329
# Epoch 31/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4084 - accuracy: 0.8335
# Epoch 32/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4084 - accuracy: 0.8336
# Epoch 33/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4077 - accuracy: 0.8345
# Epoch 34/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4072 - accuracy: 0.8346
# Epoch 35/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4071 - accuracy: 0.8349
# Epoch 36/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4068 - accuracy: 0.8351
# Epoch 37/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4063 - accuracy: 0.8347
# Epoch 38/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4063 - accuracy: 0.8356
# Epoch 39/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4058 - accuracy: 0.8350
# Epoch 40/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4056 - accuracy: 0.8351
# Epoch 41/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4051 - accuracy: 0.8354
# Epoch 42/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4051 - accuracy: 0.8349
# Epoch 43/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4045 - accuracy: 0.8351
# Epoch 44/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4045 - accuracy: 0.8347
# Epoch 45/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4044 - accuracy: 0.8350
# Epoch 46/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4042 - accuracy: 0.8350
# Epoch 47/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4037 - accuracy: 0.8361
# Epoch 48/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4036 - accuracy: 0.8364
# Epoch 49/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4036 - accuracy: 0.8361
# Epoch 50/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4030 - accuracy: 0.8344
# Epoch 51/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4034 - accuracy: 0.8370
# Epoch 52/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4032 - accuracy: 0.8360
# Epoch 53/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4030 - accuracy: 0.8357
# Epoch 54/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4028 - accuracy: 0.8361
# Epoch 55/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4027 - accuracy: 0.8364
# Epoch 56/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4024 - accuracy: 0.8363
# Epoch 57/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4024 - accuracy: 0.8364
# Epoch 58/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4022 - accuracy: 0.8367
# Epoch 59/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4022 - accuracy: 0.8355
# Epoch 60/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4021 - accuracy: 0.8361
# Epoch 61/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4020 - accuracy: 0.8364
# Epoch 62/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4017 - accuracy: 0.8369
# Epoch 63/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4018 - accuracy: 0.8361
# Epoch 64/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4015 - accuracy: 0.8357
# Epoch 65/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4014 - accuracy: 0.8364
# Epoch 66/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4011 - accuracy: 0.8366
# Epoch 67/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4012 - accuracy: 0.8363
# Epoch 68/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4013 - accuracy: 0.8366
# Epoch 69/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4012 - accuracy: 0.8355
# Epoch 70/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4007 - accuracy: 0.8367
# Epoch 71/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4009 - accuracy: 0.8363
# Epoch 72/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4010 - accuracy: 0.8363
# Epoch 73/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4007 - accuracy: 0.8354
# Epoch 74/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4008 - accuracy: 0.8363
# Epoch 75/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4007 - accuracy: 0.8355
# Epoch 76/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4006 - accuracy: 0.8365
# Epoch 77/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4005 - accuracy: 0.8361
# Epoch 78/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4008 - accuracy: 0.8359
# Epoch 79/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4003 - accuracy: 0.8355
# Epoch 80/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4004 - accuracy: 0.8367
# Epoch 81/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4002 - accuracy: 0.8363
# Epoch 82/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4003 - accuracy: 0.8370
# Epoch 83/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4002 - accuracy: 0.8374
# Epoch 84/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4001 - accuracy: 0.8355
# Epoch 85/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.4001 - accuracy: 0.8356
# Epoch 86/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4000 - accuracy: 0.8365
# Epoch 87/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.4000 - accuracy: 0.8364
# Epoch 88/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.3999 - accuracy: 0.8374
# Epoch 89/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.3998 - accuracy: 0.8363
# Epoch 90/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.3999 - accuracy: 0.8366
# Epoch 91/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.3997 - accuracy: 0.8372
# Epoch 92/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.3999 - accuracy: 0.8355
# Epoch 93/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.3997 - accuracy: 0.8357
# Epoch 94/100
# 8000/8000 [==============================] - 0s 10us/step - loss: 0.3998 - accuracy: 0.8359
# Epoch 95/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.3997 - accuracy: 0.8367
# Epoch 96/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.3996 - accuracy: 0.8367
# Epoch 97/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.3993 - accuracy: 0.8364
# Epoch 98/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.3993 - accuracy: 0.8363
# Epoch 99/100
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.3996 - accuracy: 0.8356
# Epoch 100/100
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.3994 - accuracy: 0.8357

# %% [markdown]
# # Confusion matrix

# %%
y_pred_bool = (y_pred > 0.5)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred_bool)
cm
# Out:
# array([[1543,   52],
#        [ 268,  137]])

# %% [markdown]
# # Accuracy

# %%
(1517 + 201) / 2000
# Out:
# 0.859

# %% [markdown]
# ## WHAT IS THE ACCURACY OF THE MODEL?
# giudicare il nostro modello da una sola ccuracy non è il modo migliore per valutare il nostro modello
# # K-FOLD VALIDATION
# ![1.png](attachment:1.png)

# %%
from keras.wrappers.scikit_learn import KerasClassifier 
from sklearn.model_selection import cross_val_score

# %%
def build_classifier(): 
# we can build it  
    classifier = Sequential()
    classifier.add(Dense(output_dim = 7, init = 'uniform', activation = 'relu', input_dim = 12 ))
    classifier.add(Dense(output_dim = 7, init = 'uniform', activation = 'relu'))
    classifier.add(Dense(output_dim = 1, init = 'uniform', activation = 'sigmoid')) # sigmoid 
    classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy' , metrics = ['accuracy'] )
    return classifier

#NOPE 
# h = classifier.fit(X_train, y_train, batch_size =80  , nb_epoch = 100)

# %%
clasf = KerasClassifier(build_fn = build_classifier, batch_size =80  , nb_epoch = 100)
accuracies = cross_val_score(estimator = clasf, X = X_train, y = y_train, cv = 10, n_jobs = -1  )
# n_jobs = -1 use all the CPU to do parallel computation

# %%
accuracies # this is the relevant result
# Out:
# array([0.78625   , 0.79000002, 0.80000001, 0.78250003, 0.81625003,
#        0.81      , 0.78750002, 0.79374999, 0.79874998, 0.79500002])

# %%
# let's compute the mean of the accuracies 
mean = accuracies.mean()
mean
# Out:
# 0.7960000097751617

# %%
variance = accuracies.std()
variance
# Out:
# 0.010105690527913859

# %% [markdown]
# # OVERFITTING ?
# when you have a really high accuracy.
# also when you have a high variance in cross validation.
#
# ## Dropout regularization
# At each iteration of the training, some neurons of your ANN will randomly disabled to prevent them to be dependent to each other when they learn the correlations.
#
# That prevent the neurons to learn to much and so prevent the overfitting.
#
# You can apply dropout to the layers, you can choose which layer.
# It is better to apply dropout to all the layers.
#
#
# Dropout(
# - p = float between 0 and 1. Fraction of the input unit (neurons) to drop. Start p = 0.1 and then increase p if you still have the overfitting problem.
#
#
# )

# %%
from keras.layers import Dropout

# %%
def build_classifier_dropout(): 
# we can build it  
    classifier = Sequential()
    classifier.add(Dense(output_dim = 7, init = 'uniform', activation = 'relu', input_dim = 12 ))
    classifier.add(Dropout( p = 0.1 ) )
    
    classifier.add(Dense(output_dim = 7, init = 'uniform', activation = 'relu'))
    classifier.add(Dropout( p = 0.1 ) )
    
    classifier.add(Dense(output_dim = 1, init = 'uniform', activation = 'sigmoid')) # sigmoid 
    classifier.add(Dropout( p = 0.1 ) )
    
    classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy' , metrics = ['accuracy'] )
    return classifier

# %%
clasf = KerasClassifier(build_fn = build_classifier_dropout, batch_size =80  , nb_epoch = 100)
accuracies = cross_val_score(estimator = clasf, X = X_train, y = y_train, cv = 10, n_jobs = -1  )
# n_jobs = -1 use all the CPU to do parallel computation 
mean = accuracies.mean()
mean
# Out:
# 0.7960000097751617

# %%
variance = accuracies.std()
variance
# Out:
# 0.010105690527913859

# %% [markdown]
# ## GridSearchCV
#
# GridSearchCV lets you combine an estimator with a grid search preamble to tune hyper-parameters. The method picks the optimal parameter from the grid search and uses it with the estimator selected by the user. GridSearchCV inherits the methods from the classifier, so yes, you can use the .score, .predict, etc.. methods directly through the GridSearchCV interface. If you wish to extract the best hyper-parameters identified by the grid search you can use .best_params_ and this will return the best hyper-parameter. You can then pass this hyper-parameter to your estimator separately.
#
# Using .predict directly will yield the same results as getting the best hyper-parameter through .best_param_ and then using it in your model. By understanding the underlining workings of grid search we can see why this is the case.

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense 


def build_classifier_search(optimizer): 
# we can build it  
    classifier = Sequential()
    classifier.add(Dense(output_dim = 7, init = 'uniform', activation = 'relu', input_dim = 12 ))
    classifier.add(Dense(output_dim = 7, init = 'uniform', activation = 'relu'))
    classifier.add(Dense(output_dim = 1, init = 'uniform', activation = 'sigmoid')) # sigmoid 
    classifier.compile(optimizer = optimizer, loss = 'binary_crossentropy' , metrics = ['accuracy'] )
    return classifier

clasf = KerasClassifier(build_fn = build_classifier_search)

# %%
# Let's create the dictionary whit all the hyperparameters variable
# keys and the hyperparameters we want to test 

parameters = {'batch_size': [25, 32, 100, 80],
             'nb_epoch' : [100, 500], 
             'optimizer' : ['adam', 'rmsprop'] }

grid_search = GridSearchCV(estimator = clasf, param_grid = parameters, scoring = 'accuracy', cv = 10 )

# %%
grid_search = grid_search.fit(X_train, y_train)
# Out:
# /Users/Paola/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=12, units=7, kernel_initializer="uniform")`
#   # Remove the CWD from sys.path while we load stuff.
# /Users/Paola/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=7, kernel_initializer="uniform")`
#   # This is added back by InteractiveShellApp.init_path()
# /Users/Paola/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1, kernel_initializer="uniform")`
#   if sys.path[0] == '':
# Epoch 1/1
# 7200/7200 [==============================] - 0s 40us/step - loss: 0.5473 - accuracy: 0.7961
# Epoch 1/1
# 7200/7200 [==============================] - 0s 41us/step - loss: 0.5479 - accuracy: 0.7965
# Epoch 1/1
# 7200/7200 [==============================] - 0s 40us/step - loss: 0.5862 - accuracy: 0.7936
# Epoch 1/1
# 7200/7200 [==============================] - 0s 40us/step - loss: 0.5745 - accuracy: 0.7965
# Epoch 1/1
# 7200/7200 [==============================] - 0s 41us/step - loss: 0.5420 - accuracy: 0.7936
# Epoch 1/1
# 7200/7200 [==============================] - 0s 44us/step - loss: 0.5430 - accuracy: 0.7943
# Epoch 1/1
# 7200/7200 [==============================] - 0s 46us/step - loss: 0.5443 - accuracy: 0.7964
# Epoch 1/1
# 7200/7200 [==============================] - 0s 44us/step - loss: 0.6001 - accuracy: 0.7958
# Epoch 1/1
# 7200/7200 [==============================] - 0s 43us/step - loss: 0.5549 - accuracy: 0.7947
# Epoch 1/1
# 7200/7200 [==============================] - 0s 43us/step - loss: 0.5357 - accuracy: 0.7958
# Epoch 1/1
# 7200/7200 [==============================] - 0s 39us/step - loss: 0.5661 - accuracy: 0.7964
# Epoch 1/1
# 7200/7200 [==============================] - 0s 37us/step - loss: 0.5676 - accuracy: 0.7950
# Epoch 1/1
# 7200/7200 [==============================] - 0s 36us/step - loss: 0.5987 - accuracy: 0.7936
# Epoch 1/1
# 7200/7200 [==============================] - 0s 35us/step - loss: 0.5613 - accuracy: 0.7956
# Epoch 1/1
# 7200/7200 [==============================] - 0s 36us/step - loss: 0.5727 - accuracy: 0.7929
# Epoch 1/1
# 7200/7200 [==============================] - 0s 36us/step - loss: 0.5469 - accuracy: 0.7944
# Epoch 1/1
# 7200/7200 [==============================] - 0s 36us/step - loss: 0.5585 - accuracy: 0.7958
# Epoch 1/1
# 7200/7200 [==============================] - 0s 35us/step - loss: 0.5648 - accuracy: 0.7957
# Epoch 1/1
# 7200/7200 [==============================] - 0s 36us/step - loss: 0.5589 - accuracy: 0.7946
# Epoch 1/1
# 7200/7200 [==============================] - 0s 37us/step - loss: 0.5650 - accuracy: 0.7961
# Epoch 1/1
# 7200/7200 [==============================] - 0s 42us/step - loss: 0.5549 - accuracy: 0.7964
# Epoch 1/1
# 7200/7200 [==============================] - 0s 44us/step - loss: 0.5771 - accuracy: 0.7949
# Epoch 1/1
# 7200/7200 [==============================] - 0s 41us/step - loss: 0.5803 - accuracy: 0.7946
# Epoch 1/1
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.5648 - accuracy: 0.7958
# Epoch 1/1
# 7200/7200 [==============================] - 0s 44us/step - loss: 0.5522 - accuracy: 0.7933
# Epoch 1/1
# 7200/7200 [==============================] - 0s 46us/step - loss: 0.5627 - accuracy: 0.7944
# Epoch 1/1
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.5572 - accuracy: 0.7957
# Epoch 1/1
# 7200/7200 [==============================] - 0s 46us/step - loss: 0.5514 - accuracy: 0.7951
# Epoch 1/1
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.5419 - accuracy: 0.7957
# Epoch 1/1
# 7200/7200 [==============================] - 0s 56us/step - loss: 0.5418 - accuracy: 0.7951
# Epoch 1/1
# 7200/7200 [==============================] - 0s 39us/step - loss: 0.5650 - accuracy: 0.7951
# Epoch 1/1
# 7200/7200 [==============================] - 0s 38us/step - loss: 0.6011 - accuracy: 0.7943
# Epoch 1/1
# 7200/7200 [==============================] - 0s 39us/step - loss: 0.5601 - accuracy: 0.7942
# Epoch 1/1
# 7200/7200 [==============================] - 0s 44us/step - loss: 0.5727 - accuracy: 0.7976
# Epoch 1/1
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.5523 - accuracy: 0.7932
# Epoch 1/1
# 7200/7200 [==============================] - 0s 37us/step - loss: 0.6041 - accuracy: 0.7924
# Epoch 1/1
# 7200/7200 [==============================] - 0s 39us/step - loss: 0.5523 - accuracy: 0.7964
# Epoch 1/1
# 7200/7200 [==============================] - 0s 37us/step - loss: 0.5844 - accuracy: 0.7953
# Epoch 1/1
# 7200/7200 [==============================] - 0s 36us/step - loss: 0.5686 - accuracy: 0.7950
# Epoch 1/1
# 7200/7200 [==============================] - 0s 38us/step - loss: 0.5738 - accuracy: 0.7960
# Epoch 1/1
# 7200/7200 [==============================] - 0s 37us/step - loss: 0.5634 - accuracy: 0.7971
# Epoch 1/1
# 7200/7200 [==============================] - 0s 36us/step - loss: 0.5775 - accuracy: 0.7946
# Epoch 1/1
# 7200/7200 [==============================] - 0s 37us/step - loss: 0.5816 - accuracy: 0.7946
# Epoch 1/1
# 7200/7200 [==============================] - 0s 38us/step - loss: 0.5810 - accuracy: 0.7961
# Epoch 1/1
# 7200/7200 [==============================] - 0s 36us/step - loss: 0.5896 - accuracy: 0.7924
# Epoch 1/1
# 7200/7200 [==============================] - 0s 36us/step - loss: 0.5813 - accuracy: 0.7947
# Epoch 1/1
# 7200/7200 [==============================] - 0s 35us/step - loss: 0.5805 - accuracy: 0.7956
# Epoch 1/1
# 7200/7200 [==============================] - 0s 36us/step - loss: 0.5676 - accuracy: 0.7957
# Epoch 1/1
# 7200/7200 [==============================] - 0s 35us/step - loss: 0.5564 - accuracy: 0.7957
# Epoch 1/1
# 7200/7200 [==============================] - 0s 35us/step - loss: 0.5694 - accuracy: 0.7951
# Epoch 1/1
# 7200/7200 [==============================] - 0s 33us/step - loss: 0.5761 - accuracy: 0.7944
# Epoch 1/1
# 7200/7200 [==============================] - 0s 31us/step - loss: 0.6042 - accuracy: 0.7939
# Epoch 1/1
# 7200/7200 [==============================] - 0s 31us/step - loss: 0.5814 - accuracy: 0.7942
# Epoch 1/1
# 7200/7200 [==============================] - 0s 32us/step - loss: 0.5977 - accuracy: 0.7974
# Epoch 1/1
# 7200/7200 [==============================] - 0s 32us/step - loss: 0.6004 - accuracy: 0.7928
# Epoch 1/1
# 7200/7200 [==============================] - 0s 34us/step - loss: 0.6233 - accuracy: 0.7935
# Epoch 1/1
# 7200/7200 [==============================] - 0s 31us/step - loss: 0.5774 - accuracy: 0.7969
# Epoch 1/1
# 7200/7200 [==============================] - 0s 37us/step - loss: 0.5720 - accuracy: 0.7962
# Epoch 1/1
# 7200/7200 [==============================] - 0s 36us/step - loss: 0.6203 - accuracy: 0.7935
# Epoch 1/1
# 7200/7200 [==============================] - 0s 35us/step - loss: 0.5953 - accuracy: 0.7937
# Epoch 1/1
# 7200/7200 [==============================] - 0s 38us/step - loss: 0.5836 - accuracy: 0.7964
# Epoch 1/1
# 7200/7200 [==============================] - 0s 40us/step - loss: 0.5675 - accuracy: 0.7947
# Epoch 1/1
# 7200/7200 [==============================] - 0s 37us/step - loss: 0.5657 - accuracy: 0.7937
# Epoch 1/1
# 7200/7200 [==============================] - 0s 39us/step - loss: 0.5752 - accuracy: 0.7957
# Epoch 1/1
# 7200/7200 [==============================] - 0s 38us/step - loss: 0.5787 - accuracy: 0.7926
# Epoch 1/1
# 7200/7200 [==============================] - 0s 38us/step - loss: 0.5771 - accuracy: 0.7932
# Epoch 1/1
# 7200/7200 [==============================] - 0s 36us/step - loss: 0.5885 - accuracy: 0.7964
# Epoch 1/1
# 7200/7200 [==============================] - 0s 38us/step - loss: 0.5927 - accuracy: 0.7951
# Epoch 1/1
# 7200/7200 [==============================] - 0s 37us/step - loss: 0.6636 - accuracy: 0.7926
# Epoch 1/1
# 7200/7200 [==============================] - 0s 43us/step - loss: 0.5800 - accuracy: 0.7960
# Epoch 1/1
# 7200/7200 [==============================] - 0s 33us/step - loss: 0.5843 - accuracy: 0.7957
# Epoch 1/1
# 7200/7200 [==============================] - 0s 33us/step - loss: 0.5721 - accuracy: 0.7965
# Epoch 1/1
# 7200/7200 [==============================] - 0s 32us/step - loss: 0.5695 - accuracy: 0.7956
# Epoch 1/1
# 7200/7200 [==============================] - 0s 31us/step - loss: 0.6073 - accuracy: 0.7942
# Epoch 1/1
# 7200/7200 [==============================] - 0s 32us/step - loss: 0.6014 - accuracy: 0.7929
# Epoch 1/1
# 7200/7200 [==============================] - 0s 31us/step - loss: 0.5765 - accuracy: 0.7944
# Epoch 1/1
# 7200/7200 [==============================] - 0s 32us/step - loss: 0.5961 - accuracy: 0.7939
# Epoch 1/1
# 7200/7200 [==============================] - 0s 32us/step - loss: 0.6029 - accuracy: 0.7953
# Epoch 1/1
# 7200/7200 [==============================] - 0s 31us/step - loss: 0.5956 - accuracy: 0.7951
# Epoch 1/1
# 7200/7200 [==============================] - 0s 32us/step - loss: 0.5930 - accuracy: 0.7950
# Epoch 1/1
# 7200/7200 [==============================] - 0s 22us/step - loss: 0.6719 - accuracy: 0.7953
# Epoch 1/1
# 7200/7200 [==============================] - 0s 22us/step - loss: 0.6793 - accuracy: 0.7882
# Epoch 1/1
# 7200/7200 [==============================] - 0s 22us/step - loss: 0.6703 - accuracy: 0.7956
# Epoch 1/1
# 7200/7200 [==============================] - 0s 21us/step - loss: 0.6811 - accuracy: 0.7890
# Epoch 1/1
# 7200/7200 [==============================] - 0s 22us/step - loss: 0.6792 - accuracy: 0.7890
# Epoch 1/1
# 7200/7200 [==============================] - 0s 21us/step - loss: 0.6763 - accuracy: 0.7936
# Epoch 1/1
# 7200/7200 [==============================] - 0s 22us/step - loss: 0.6766 - accuracy: 0.7904
# Epoch 1/1
# 7200/7200 [==============================] - 0s 21us/step - loss: 0.6754 - accuracy: 0.7925
# Epoch 1/1
# 7200/7200 [==============================] - 0s 22us/step - loss: 0.6730 - accuracy: 0.7947
# Epoch 1/1
# 7200/7200 [==============================] - 0s 22us/step - loss: 0.6764 - accuracy: 0.7925
# Epoch 1/1
# 7200/7200 [==============================] - 0s 21us/step - loss: 0.6652 - accuracy: 0.7935
# Epoch 1/1
# 7200/7200 [==============================] - 0s 20us/step - loss: 0.6779 - accuracy: 0.7889
# Epoch 1/1
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.6687 - accuracy: 0.7939
# Epoch 1/1
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.6651 - accuracy: 0.7939
# Epoch 1/1
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.6688 - accuracy: 0.7917
# Epoch 1/1
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.6701 - accuracy: 0.7901
# Epoch 1/1
# 7200/7200 [==============================] - 0s 20us/step - loss: 0.6650 - accuracy: 0.7961
# Epoch 1/1
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.6749 - accuracy: 0.7894
# Epoch 1/1
# 7200/7200 [==============================] - 0s 20us/step - loss: 0.6668 - accuracy: 0.7912
# Epoch 1/1
# 7200/7200 [==============================] - 0s 20us/step - loss: 0.6696 - accuracy: 0.7936
# Epoch 1/1
# 7200/7200 [==============================] - 0s 21us/step - loss: 0.6803 - accuracy: 0.7897
# Epoch 1/1
# 7200/7200 [==============================] - 0s 35us/step - loss: 0.6785 - accuracy: 0.7893
# Epoch 1/1
# 7200/7200 [==============================] - 0s 32us/step - loss: 0.6732 - accuracy: 0.7914
# Epoch 1/1
# 7200/7200 [==============================] - 0s 26us/step - loss: 0.6772 - accuracy: 0.7904
# Epoch 1/1
# 7200/7200 [==============================] - 0s 26us/step - loss: 0.6760 - accuracy: 0.7928
# Epoch 1/1
# 7200/7200 [==============================] - 0s 29us/step - loss: 0.6777 - accuracy: 0.7921
# Epoch 1/1
# 7200/7200 [==============================] - 0s 25us/step - loss: 0.6739 - accuracy: 0.7942
# Epoch 1/1
# 7200/7200 [==============================] - 0s 21us/step - loss: 0.6804 - accuracy: 0.7894
# Epoch 1/1
# 7200/7200 [==============================] - 0s 21us/step - loss: 0.6732 - accuracy: 0.7942
# Epoch 1/1
# 7200/7200 [==============================] - 0s 22us/step - loss: 0.6786 - accuracy: 0.7883
# Epoch 1/1
# 7200/7200 [==============================] - 0s 24us/step - loss: 0.6661 - accuracy: 0.7943
# Epoch 1/1
# 7200/7200 [==============================] - 0s 21us/step - loss: 0.6655 - accuracy: 0.7937
# Epoch 1/1
# 7200/7200 [==============================] - 0s 20us/step - loss: 0.6758 - accuracy: 0.7875
# Epoch 1/1
# 7200/7200 [==============================] - 0s 23us/step - loss: 0.6685 - accuracy: 0.7942
# Epoch 1/1
# 7200/7200 [==============================] - 0s 21us/step - loss: 0.6629 - accuracy: 0.7937
# Epoch 1/1
# 7200/7200 [==============================] - 0s 20us/step - loss: 0.6704 - accuracy: 0.7899
# Epoch 1/1
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.6690 - accuracy: 0.7893
# Epoch 1/1
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.6783 - accuracy: 0.7864
# Epoch 1/1
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.6720 - accuracy: 0.7937
# Epoch 1/1
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.6631 - accuracy: 0.7958
# Epoch 1/1
# 7200/7200 [==============================] - 0s 26us/step - loss: 0.6633 - accuracy: 0.7957
# Epoch 1/1
# 7200/7200 [==============================] - 0s 25us/step - loss: 0.6660 - accuracy: 0.7944
# Epoch 1/1
# 7200/7200 [==============================] - 0s 24us/step - loss: 0.6668 - accuracy: 0.7940
# Epoch 1/1
# 7200/7200 [==============================] - 0s 26us/step - loss: 0.6716 - accuracy: 0.7914
# Epoch 1/1
# 7200/7200 [==============================] - 0s 24us/step - loss: 0.6778 - accuracy: 0.7871
# Epoch 1/1
# 7200/7200 [==============================] - 0s 25us/step - loss: 0.6702 - accuracy: 0.7903
# Epoch 1/1
# 7200/7200 [==============================] - 0s 24us/step - loss: 0.6685 - accuracy: 0.7917
# Epoch 1/1
# 7200/7200 [==============================] - 0s 26us/step - loss: 0.6697 - accuracy: 0.7922
# Epoch 1/1
# 7200/7200 [==============================] - 0s 25us/step - loss: 0.6773 - accuracy: 0.7897
# Epoch 1/1
# 7200/7200 [==============================] - 0s 23us/step - loss: 0.6625 - accuracy: 0.7957
# Epoch 1/1
# 7200/7200 [==============================] - 0s 22us/step - loss: 0.6559 - accuracy: 0.7946
# Epoch 1/1
# 7200/7200 [==============================] - 0s 20us/step - loss: 0.6577 - accuracy: 0.7967
# Epoch 1/1
# 7200/7200 [==============================] - 0s 20us/step - loss: 0.6592 - accuracy: 0.7926
# Epoch 1/1
# 7200/7200 [==============================] - 0s 20us/step - loss: 0.6657 - accuracy: 0.7911
# Epoch 1/1
# 7200/7200 [==============================] - 0s 20us/step - loss: 0.6601 - accuracy: 0.7900
# Epoch 1/1
# 7200/7200 [==============================] - 0s 21us/step - loss: 0.6615 - accuracy: 0.7901
# Epoch 1/1
# 7200/7200 [==============================] - 0s 20us/step - loss: 0.6543 - accuracy: 0.7964
# Epoch 1/1
# 7200/7200 [==============================] - 0s 20us/step - loss: 0.6578 - accuracy: 0.7943
# Epoch 1/1
# 7200/7200 [==============================] - 0s 20us/step - loss: 0.6591 - accuracy: 0.7939
# Epoch 1/1
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.6742 - accuracy: 0.7892
# Epoch 1/1
# 7200/7200 [==============================] - 0s 23us/step - loss: 0.6696 - accuracy: 0.7940
# Epoch 1/1
# 7200/7200 [==============================] - 0s 23us/step - loss: 0.6751 - accuracy: 0.7887
# Epoch 1/1
# 7200/7200 [==============================] - 0s 24us/step - loss: 0.6600 - accuracy: 0.7956
# Epoch 1/1
# 7200/7200 [==============================] - 0s 23us/step - loss: 0.6625 - accuracy: 0.7972
# Epoch 1/1
# 7200/7200 [==============================] - 0s 23us/step - loss: 0.6604 - accuracy: 0.7936
# Epoch 1/1
# 7200/7200 [==============================] - 0s 23us/step - loss: 0.6666 - accuracy: 0.7942
# Epoch 1/1
# 7200/7200 [==============================] - 0s 23us/step - loss: 0.6697 - accuracy: 0.7926
# Epoch 1/1
# 7200/7200 [==============================] - 0s 23us/step - loss: 0.6691 - accuracy: 0.7940
# Epoch 1/1
# 7200/7200 [==============================] - 0s 23us/step - loss: 0.6661 - accuracy: 0.7908
# Epoch 1/1
# 7200/7200 [==============================] - 0s 23us/step - loss: 0.6603 - accuracy: 0.7953
# Epoch 1/1
# 7200/7200 [==============================] - 0s 21us/step - loss: 0.6689 - accuracy: 0.7894
# Epoch 1/1
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.6587 - accuracy: 0.7961
# Epoch 1/1
# 7200/7200 [==============================] - 0s 20us/step - loss: 0.6535 - accuracy: 0.7940
# Epoch 1/1
# 7200/7200 [==============================] - 0s 20us/step - loss: 0.6522 - accuracy: 0.7957
# Epoch 1/1
# 7200/7200 [==============================] - 0s 20us/step - loss: 0.6525 - accuracy: 0.7937
# Epoch 1/1
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.6683 - accuracy: 0.7915
# Epoch 1/1
# 7200/7200 [==============================] - 0s 20us/step - loss: 0.6529 - accuracy: 0.7960
# Epoch 1/1
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.6574 - accuracy: 0.7932
# Epoch 1/1
# 7200/7200 [==============================] - 0s 20us/step - loss: 0.6618 - accuracy: 0.7925
# Epoch 1/1
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.6523 - accuracy: 0.7961
# Epoch 1/1
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.5721 - accuracy: 0.7941

# %%
best_parameters = grid_search.best_params_
best_parameters
# Out:
# {'batch_size': 25, 'nb_epoch': 100, 'optimizer': 'adam'}

# %%
best_accuracy = grid_search.best_score_
best_accuracy
# Out:
# 0.796
