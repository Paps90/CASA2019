# %% [markdown]
# # FACE DETECTOR

# %%
import cv2
import sys


image = cv2.imread('faces.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.3,
    minNeighbors=3,
    minSize=(30, 30)
)

print("[INFO] Found {0} Faces!".format(len(faces)))

for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)

status = cv2.imwrite('faces_detected.jpg', image)
print("[INFO] Image faces_detected.jpg written to filesystem: ", status)
# Out:
# [INFO] Found 4 Faces!
# [INFO] Image faces_detected.jpg written to filesystem:  True

# %%
from IPython.core.display import Image, display
display(Image('faces.png', width=1900, unconfined=True))

# %%
from IPython.core.display import Image, display
display(Image('faces_detected.jpg', width=1900, unconfined=True))

# %% [markdown]
# Here you have a list od .xml file to detect:
#     - right eye
#     - left eye
#     - frontal face
#     - face
#     - full body
#     - mouth
#     - nose
#     - ...
#
# http://alereimondo.no-ip.org/OpenCV/34

# %% [markdown]
# # CROP IMAGE

# %%
face_crop = []


for f in faces:
    x, y, w, h = [ v for v in f ]
    cv2.rectangle(image, (x,y), (x+w, y+h), (255,0,0), 3)
    # Define the region of interest in the image  
    face_crop.append(image[y:y+h, x:x+w])
    print("ok")

contatore = 0 
for face in face_crop:
    faccia = 'face_' + str(contatore) + '.jpg'
    
    status = cv2.imwrite(faccia, face)
    contatore= contatore + 1 
    
    display(Image(faccia, width=300, unconfined=True))
# Out:
# ok
# ok
# ok
# ok
